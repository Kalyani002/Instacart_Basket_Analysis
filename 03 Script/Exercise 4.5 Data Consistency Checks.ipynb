# %% [markdown]
# ## Exercise 4.5 Data Consistency Checks

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Turn the project folder path into a string 
path = r'C:\Users\Kalyani\Documents\Instacart_Basket_Analysis'

# %%
path
# Out:
# 'C:\\Users\\Kalyani\\Documents\\Instacart_Basket_Analysis'

# %%
##  import the “products.csv” data set from your “Original Data” folder as df_prods
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original_data', 'products.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
### orders_wrangled.csv” data set from your “Prepared Data” folder as df_ords
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared_data', 'orders_wrangled.csv'), index_col = False)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_previous_order
# 0                        NaN
# 1                       15.0
# 2                       21.0
# 3                       29.0
# 4                       28.0

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_previous_order
# count       3.421083e+06               3.214874e+06
# mean        1.345202e+01               1.111484e+01
# std         4.226088e+00               9.206737e+00
# min         0.000000e+00               0.000000e+00
# 25%         1.000000e+01               4.000000e+00
# ...

# %% [markdown]
# ## Mixed-Type Data

# %%
# create a dataframe
df_test = pd.DataFrame()

# %%
# Create a mixed-type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Check for mixed type
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix
# C:\Users\Kalyani\AppData\Local\Temp\ipykernel_5360\1824402076.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)

# %% [markdown]
# ## Missing values

# %%
# Finding Missing Values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
## Actually view these missing values(16 value)
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
## Addressing Missing Values
df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# ## Duplicates

# %%
## Duplicates -- Finding Duplicates
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# ## Tidying Up and Exporting Changes

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data', 'Prepared_data', 'products-checked.csv'))

# %% [markdown]
# ## Exercise 4.5 Data Consistency Checks (Task-work)

# %% [markdown]
# # Step 2:-

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_previous_order
# 0                        NaN
# 1                       15.0
# 2                       21.0
# 3                       29.0
# 4                       28.0

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_previous_order
# count       3.421083e+06               3.214874e+06
# mean        1.345202e+01               1.111484e+01
# std         4.226088e+00               9.206737e+00
# min         0.000000e+00               0.000000e+00
# 25%         1.000000e+01               4.000000e+00
# ...

# %% [markdown]
# # Step 03:-

# %%
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %%
# There is no mixed data type present in df_ords dataframe.
df_ords.dtypes
# Out:
# order_id                       int64
# user_id                        int64
# order_number                   int64
# order_day_of_week              int64
# order_hour_of_day              int64
# days_since_previous_order    float64
# dtype: object

# %% [markdown]
# # Step 05:-

# %%
df_ords.isnull().sum()
# Out:
# order_id                          0
# user_id                           0
# order_number                      0
# order_day_of_week                 0
# order_hour_of_day                 0
# days_since_previous_order    206209
# dtype: int64

# %%
# There are 206209 missing values present in the 'days_since_previous_order' column
# There is no data available about the customer's purchase since his last order, that could be because of data ambiguity. 
# This large amount of data is missing, it might be because it could be the customer's first order with Instacart.
# The historical data is not retained for is not available.
# Removing or imputing missing values may change important data about customers. So we should not change any data.

# %%
df_ords.head(15)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   1187899        1            11                  4                  8
# 11   2168274        2             1                  2                 11
# ...

# %% [markdown]
# # Step 7 Finding Duplicates

# %%
df_ords_dups = df_ords[df_ords.duplicated()]
# This code creates a new subset of df_otds_clean—df_dups—containing only rows that are duplicates. 
## The duplicated() function is what identifies duplicate rows. 
### It’s run on the df_ords_clean dataframe. Any duplicate rows that it finds are saved within the new df_ords_dups dataframe

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_previous_order]
# Index: []

# %%
# Dataframe returns empty which means there are no duplicate values.

# %%
df_ords_dups.shape
# Out:
# (0, 6)

# %% [markdown]
# # Step 8 Exporting .csv files

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data', 'Prepared_data', 'products-checked.csv'), index = False)
df_ords.to_csv(os.path.join(path, '02 Data','Prepared_data', 'orders_cleaned.csv'), index = False)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_previous_order
# 0                        NaN
# 1                       15.0
# 2                       21.0
# 3                       29.0
# 4                       28.0

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3
