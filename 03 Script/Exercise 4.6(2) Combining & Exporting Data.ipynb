# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Turn the project folder path into a string 
path = r'C:\Users\Kalyani\Documents\Instacart_Basket_Analysis'

# %%
path
# Out:
# 'C:\\Users\\Kalyani\\Documents\\Instacart_Basket_Analysis'

# %% [markdown]
# # Step 03

# %%
## importing orders_products_combined.pkl” data set from your “Prepared Data” folder as df_ords_prods_combined
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared_data', 'orders_products_combined.pkl'))

# %%
df_ords_prods_combined.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_previous_order  product_id  add_to_cart_order  reordered _merge
# 0                        NaN         196                  1          0   both
# 1                        NaN       14084                  2          0   both
# 2                        NaN       12427                  3          0   both
# 3                        NaN       26088                  4          0   both
# 4                        NaN       26405                  5          0   both

# %% [markdown]
# # Step 04

# %%
# Checking the shape of the imported dataframe
df_ords_prods_combined.shape
# Out:
# (32434489, 10)

# %%
# Importing 'df_prod' dataframe from prepared data
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared_data', 'products_checked.csv'), index_col = False)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Drop unnecessary columns
df_prods = df_prods.drop(['Unnamed: 0'], axis=1)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Check the shape of 'df_prods'
df_prods.shape
# Out:
# (49672, 5)

# %% [markdown]
# # Step 5

# %%
# Mergeing two dataframes on common column 'product_id'.
df_ords_prods_merge = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_ords_prods_merge = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10487, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10468 @Substitution("")
#   10469 @Appender(_merge_doc, indents=2)
#   10470 def merge(
#    (...)
#   10483     validate: MergeValidate | None = None,
#   10484 ) -> DataFrame:
#   10485     from pandas.core.reshape.merge import merge
# > 10487     return merge(
#   10488         self,
#   10489         right,
#   10490         how=how,
#   10491         on=on,
#   10492         left_on=left_on,
#   10493         right_on=right_on,
#   10494         left_index=left_index,
# ...

# %% [markdown]
# # There is '_merge' column that already exists in df_ords_prods_combined' so need to drop that column first before merging two dataframes

# %%
# Droppin '_merge' column
df_ords_prods_combined = df_ords_prods_combined.drop(['_merge'], axis = 1)

# %%
# Checking output
df_ords_prods_combined
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_previous_order  product_id  \
# 0                         8                        NaN         196
# 1                         8                        NaN       14084
# ...

# %%
# Mergeing two dataframes, 'df_prods' and 'df_ords_prods_combined' on common column 'product_id'.
df_ords_prods_merge = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)

# %%
# Checking an Output
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                  6                 11
# 1   1977647      138            30                  6                 17
# 2    389851      709             2                  0                 21
# 3    652770      764             1                  3                 13
# 4   1813452      764             3                  4                 17
#
#    days_since_previous_order  add_to_cart_order  reordered _merge
# ...

# %%
# Checking shape of newly merged dataframe
df_ords_prods_merge.shape
# Out:
# (32404859, 14)

# %% [markdown]
# # Step 6

# %%
# Confirm the results of the merge using the merge flag.
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# The output af merge using merge flag indicated newly merged dataframe has 32404859 rows. As 'inner join' is default here 
## so each of those rows have information found in both input dataframes.

# %% [markdown]
# # Step 7

# %%
# Export data to pkl
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared_data', 'ords_prods_merge.pkl'))
